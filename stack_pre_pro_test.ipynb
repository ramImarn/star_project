# %%
import os
import glob
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, LeakyReLU
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
import tensorflow as tf
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
files='F:\\Exprement\\saturn\\time_series\\star_pro\\'
scaler = StandardScaler()

for a in os.listdir(files):
    name, ext = os.path.splitext(a)
    if ext == ".csv":
        #ff=os.path.join(files,a)
        file=pd.read_csv(os.path.join(files,a))
        file=file.replace({' -   ': '0', '_': '0', '-': '0', ',': ''}, regex=True)
        file=file.iloc[:,1:]
        if name == "training_file":
            trainX = scaler.fit_transform(file)
            trainY = trainX [:,33:34]
        elif name == "validation_file":
            val_file=file.iloc[:,1:]
            valX = scaler.fit_transform(file)
            valY = valX [:,33:34]
        elif name == "testing_file":
            test_file=file.iloc[:,1:]
            testX = scaler.fit_transform(file)
            testY = testX [:,33:34]

# %%
valX.shape,testX.shape
# Out:
# ((83, 90), (39, 90))

# %%
win_length=30
batch_size=5

train_generator=TimeseriesGenerator(trainX,trainY,length=win_length,sampling_rate=1,batch_size=batch_size)
val_generator=TimeseriesGenerator(valX,valY,length=win_length,sampling_rate=1,batch_size=batch_size)
test_generator=TimeseriesGenerator(testX,testY,length=win_length,sampling_rate=1,batch_size=batch_size)

train_generator[0]
# Out:
# (array([[[-0.71517283, -0.71548899, -0.71594813, ...,  1.0548094 ,
#            0.99169658, -0.04852009],
#          [-0.71518977, -0.71584857, -0.7161427 , ...,  1.02663975,
#            1.03944782, -0.04797716],
#          [-0.71526654, -0.71592429, -0.71612256, ...,  1.02663975,
#            1.03944782, -0.04803052],
#          ...,
#          [-0.71718294, -0.71731849, -0.71779983, ..., -1.42917037,
#           -1.54244988, -0.064532  ],
#          [-0.71708103, -0.71698414, -0.71760976, ..., -1.42917037,
#           -1.54244988, -0.06119682],
#          [-0.71679917, -0.71691474, -0.71731902, ..., -1.34038114,
#           -1.47420651, -0.05868767]],
#
#         [[-0.71518977, -0.71584857, -0.7161427 , ...,  1.02663975,
#            1.03944782, -0.04797716],
#          [-0.71526654, -0.71592429, -0.71612256, ...,  1.02663975,
#            1.03944782, -0.04803052],
#          [-0.71533663, -0.7158612 , -0.71610244, ...,  0.75300639,
#            0.96649763, -0.04822858],
#          ...,
#          [-0.71708103, -0.71698414, -0.71760976, ..., -1.42917037,
#           -1.54244988, -0.06119682],
#          [-0.71679917, -0.71691474, -0.71731902, ..., -1.34038114,
#           -1.47420651, -0.05868767],
#          [-0.71660947, -0.71708507, -0.71745768, ..., -1.34038114,
#           -1.47420651, -0.05677227]],
#
#         [[-0.71526654, -0.71592429, -0.71612256, ...,  1.02663975,
#            1.03944782, -0.04803052],
#          [-0.71533663, -0.7158612 , -0.71610244, ...,  0.75300639,
#            0.96649763, -0.04822858],
#          [-0.71534891, -0.71595584, -0.71630372, ...,  0.75300639,
#            0.96649763, -0.04877079],
#          ...,
#          [-0.71679917, -0.71691474, -0.71731902, ..., -1.34038114,
#           -1.47420651, -0.05868767],
#          [-0.71660947, -0.71708507, -0.71745768, ..., -1.34038114,
#           -1.47420651, -0.05677227],
#          [-0.7166073 , -0.71654883, -0.71712111, ..., -1.1328364 ,
#           -1.33303957, -0.05565498]],
#
#         [[-0.71533663, -0.7158612 , -0.71610244, ...,  0.75300639,
#            0.96649763, -0.04822858],
#          [-0.71534891, -0.71595584, -0.71630372, ...,  0.75300639,
#            0.96649763, -0.04877079],
#          [-0.71545018, -0.71613835, -0.71707527, ...,  0.5211418 ,
#            0.7843369 , -0.04973458],
#          ...,
#          [-0.71660947, -0.71708507, -0.71745768, ..., -1.34038114,
#           -1.47420651, -0.05677227],
#          [-0.7166073 , -0.71654883, -0.71712111, ..., -1.1328364 ,
#           -1.33303957, -0.05565498],
#          [-0.71645093, -0.71643529, -0.71695981, ..., -1.1328364 ,
#           -1.33303957, -0.05461613]],
#
#         [[-0.71534891, -0.71595584, -0.71630372, ...,  0.75300639,
#            0.96649763, -0.04877079],
#          [-0.71545018, -0.71613835, -0.71707527, ...,  0.5211418 ,
#            0.7843369 , -0.04973458],
#          [-0.71572033, -0.71410108, -0.7162062 , ...,  0.5211418 ,
#            0.7843369 , -0.04975171],
#          ...,
#          [-0.7166073 , -0.71654883, -0.71712111, ..., -1.1328364 ,
#           -1.33303957, -0.05565498],
#          [-0.71645093, -0.71643529, -0.71695981, ..., -1.1328364 ,
#           -1.33303957, -0.05461613],
#          [-0.71629388, -0.71668132, -0.71775959, ..., -1.13318757,
#           -1.23200954, -0.05353786]]]),
#  array([[-0.71688105],
#         [-0.716764  ],
#         [-0.71662862],
#         [-0.71659895],
#         [-0.71677795]]))

# %%
model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(win_length, trainX.shape[1]), return_sequences=True))
model.add(LeakyReLU(alpha=0.5))
model.add(LSTM(32, activation='relu', return_sequences=False))
model.add(LeakyReLU(alpha=0.5))
model.add(Dropout(0.2))
model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 30, 64)            39680
#
#  leaky_re_lu (LeakyReLU)     (None, 30, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 32)                0
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 52,129
# Trainable params: 52,129
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.losses.MeanAbsoluteError(),optimizer=tf.optimizers.Adam(1e-4),metrics=[tf.metrics.MeanAbsoluteError()])

# %%
# fit the model
history = model.fit(train_generator, validation_data=val_generator, epochs=50, shuffle=False, verbose=1)
model.save('star_pro_weights_3.1.h5')
# Out:
# Epoch 1/50
# 571/571 [==============================] - 14s 20ms/step - loss: 0.4401 - mean_absolute_error: 0.4401 - val_loss: 0.8316 - val_mean_absolute_error: 0.8316
# Epoch 2/50
# 571/571 [==============================] - 11s 19ms/step - loss: 0.2388 - mean_absolute_error: 0.2388 - val_loss: 0.6511 - val_mean_absolute_error: 0.6511
# Epoch 3/50
# 571/571 [==============================] - 11s 18ms/step - loss: 0.2030 - mean_absolute_error: 0.2030 - val_loss: 0.6184 - val_mean_absolute_error: 0.6184
# Epoch 4/50
# 571/571 [==============================] - 13s 22ms/step - loss: 0.1682 - mean_absolute_error: 0.1682 - val_loss: 0.6930 - val_mean_absolute_error: 0.6930
# Epoch 5/50
# 571/571 [==============================] - 15s 26ms/step - loss: 0.1520 - mean_absolute_error: 0.1520 - val_loss: 0.5889 - val_mean_absolute_error: 0.5889
# Epoch 6/50
# 571/571 [==============================] - 11s 18ms/step - loss: 0.1467 - mean_absolute_error: 0.1467 - val_loss: 0.5929 - val_mean_absolute_error: 0.5929
# Epoch 7/50
# 571/571 [==============================] - 10s 18ms/step - loss: 0.1406 - mean_absolute_error: 0.1406 - val_loss: 0.5930 - val_mean_absolute_error: 0.5930
# Epoch 8/50
# 571/571 [==============================] - 13s 23ms/step - loss: 0.1368 - mean_absolute_error: 0.1368 - val_loss: 0.5321 - val_mean_absolute_error: 0.5321
# Epoch 9/50
# 571/571 [==============================] - 10s 18ms/step - loss: 0.1377 - mean_absolute_error: 0.1377 - val_loss: 0.6071 - val_mean_absolute_error: 0.6071
# Epoch 10/50
# 571/571 [==============================] - 13s 23ms/step - loss: 0.1519 - mean_absolute_error: 0.1519 - val_loss: 0.5709 - val_mean_absolute_error: 0.5709
# Epoch 11/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.1319 - mean_absolute_error: 0.1319 - val_loss: 0.5447 - val_mean_absolute_error: 0.5447
# Epoch 12/50
# 571/571 [==============================] - 8s 15ms/step - loss: 0.1266 - mean_absolute_error: 0.1266 - val_loss: 0.5480 - val_mean_absolute_error: 0.5480
# Epoch 13/50
# 571/571 [==============================] - 8s 14ms/step - loss: 0.1296 - mean_absolute_error: 0.1296 - val_loss: 0.5472 - val_mean_absolute_error: 0.5472
# Epoch 14/50
# 571/571 [==============================] - 11s 18ms/step - loss: 0.1235 - mean_absolute_error: 0.1235 - val_loss: 0.5594 - val_mean_absolute_error: 0.5594
# Epoch 15/50
# 571/571 [==============================] - 11s 19ms/step - loss: 0.1200 - mean_absolute_error: 0.1200 - val_loss: 0.5397 - val_mean_absolute_error: 0.5397
# Epoch 16/50
# 571/571 [==============================] - 11s 19ms/step - loss: 0.1137 - mean_absolute_error: 0.1137 - val_loss: 0.5837 - val_mean_absolute_error: 0.5837
# Epoch 17/50
# 571/571 [==============================] - 11s 19ms/step - loss: 0.1137 - mean_absolute_error: 0.1137 - val_loss: 0.5552 - val_mean_absolute_error: 0.5552
# Epoch 18/50
# 571/571 [==============================] - 12s 21ms/step - loss: 0.1028 - mean_absolute_error: 0.1028 - val_loss: 0.5459 - val_mean_absolute_error: 0.5459
# Epoch 19/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.1018 - mean_absolute_error: 0.1018 - val_loss: 0.5437 - val_mean_absolute_error: 0.5437
# Epoch 20/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0952 - mean_absolute_error: 0.0952 - val_loss: 0.5577 - val_mean_absolute_error: 0.5577
# Epoch 21/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.1024 - mean_absolute_error: 0.1024 - val_loss: 0.5223 - val_mean_absolute_error: 0.5223
# Epoch 22/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0993 - mean_absolute_error: 0.0993 - val_loss: 0.5400 - val_mean_absolute_error: 0.5400
# Epoch 23/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.1039 - mean_absolute_error: 0.1039 - val_loss: 0.5523 - val_mean_absolute_error: 0.5523
# Epoch 24/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.1051 - mean_absolute_error: 0.1051 - val_loss: 0.5449 - val_mean_absolute_error: 0.5449
# Epoch 25/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.1004 - mean_absolute_error: 0.1004 - val_loss: 0.5602 - val_mean_absolute_error: 0.5602
# Epoch 26/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.1156 - mean_absolute_error: 0.1156 - val_loss: 0.5348 - val_mean_absolute_error: 0.5348
# Epoch 27/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0966 - mean_absolute_error: 0.0966 - val_loss: 0.5296 - val_mean_absolute_error: 0.5296
# Epoch 28/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0959 - mean_absolute_error: 0.0959 - val_loss: 0.5549 - val_mean_absolute_error: 0.5549
# Epoch 29/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0934 - mean_absolute_error: 0.0934 - val_loss: 0.5314 - val_mean_absolute_error: 0.5314
# Epoch 30/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0909 - mean_absolute_error: 0.0909 - val_loss: 0.5786 - val_mean_absolute_error: 0.5786
# Epoch 31/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0883 - mean_absolute_error: 0.0883 - val_loss: 0.5309 - val_mean_absolute_error: 0.5309
# Epoch 32/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0904 - mean_absolute_error: 0.0904 - val_loss: 0.5485 - val_mean_absolute_error: 0.5485
# Epoch 33/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0896 - mean_absolute_error: 0.0896 - val_loss: 0.5587 - val_mean_absolute_error: 0.5587
# Epoch 34/50
# 571/571 [==============================] - 9s 17ms/step - loss: 0.0920 - mean_absolute_error: 0.0920 - val_loss: 0.5148 - val_mean_absolute_error: 0.5148
# Epoch 35/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.0976 - mean_absolute_error: 0.0976 - val_loss: 0.5497 - val_mean_absolute_error: 0.5497
# Epoch 36/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0888 - mean_absolute_error: 0.0888 - val_loss: 0.5300 - val_mean_absolute_error: 0.5300
# Epoch 37/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0879 - mean_absolute_error: 0.0879 - val_loss: 0.5597 - val_mean_absolute_error: 0.5597
# Epoch 38/50
# 571/571 [==============================] - 9s 17ms/step - loss: 0.0927 - mean_absolute_error: 0.0927 - val_loss: 0.5692 - val_mean_absolute_error: 0.5692
# Epoch 39/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0932 - mean_absolute_error: 0.0932 - val_loss: 0.5412 - val_mean_absolute_error: 0.5412
# Epoch 40/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.0875 - mean_absolute_error: 0.0875 - val_loss: 0.5641 - val_mean_absolute_error: 0.5641
# Epoch 41/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0855 - mean_absolute_error: 0.0855 - val_loss: 0.5304 - val_mean_absolute_error: 0.5304
# Epoch 42/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0897 - mean_absolute_error: 0.0897 - val_loss: 0.5661 - val_mean_absolute_error: 0.5661
# Epoch 43/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0868 - mean_absolute_error: 0.0868 - val_loss: 0.5414 - val_mean_absolute_error: 0.5414
# Epoch 44/50
# 571/571 [==============================] - 9s 16ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - val_loss: 0.5627 - val_mean_absolute_error: 0.5627
# Epoch 45/50
# 571/571 [==============================] - 9s 17ms/step - loss: 0.0843 - mean_absolute_error: 0.0843 - val_loss: 0.5424 - val_mean_absolute_error: 0.5424
# Epoch 46/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.0853 - mean_absolute_error: 0.0853 - val_loss: 0.5366 - val_mean_absolute_error: 0.5366
# Epoch 47/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.0836 - mean_absolute_error: 0.0836 - val_loss: 0.5486 - val_mean_absolute_error: 0.5486
# Epoch 48/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.0860 - mean_absolute_error: 0.0860 - val_loss: 0.5462 - val_mean_absolute_error: 0.5462
# Epoch 49/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.0887 - mean_absolute_error: 0.0887 - val_loss: 0.5353 - val_mean_absolute_error: 0.5353
# Epoch 50/50
# 571/571 [==============================] - 10s 17ms/step - loss: 0.0844 - mean_absolute_error: 0.0844 - val_loss: 0.5676 - val_mean_absolute_error: 0.5676

# %%
model.evaluate_generator(test_generator,verbose=0)
# Out:
# C:\Users\jaisri\AppData\Local\Temp\ipykernel_2744\267665090.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   model.evaluate_generator(test_generator,verbose=0)
# [0.316337525844574, 0.316337525844574]

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

# %%
from tensorflow.keras.models import load_model
model_1=load_model('star_pro_weights_3.1.h5', compile=False)

# %%
# testing prediction

# %%
pre_df=[]
tru_df=[]

for i in range(len(test_generator)):
    tt=model_1.predict(test_generator[i][0])
    prediction_copies = np.repeat(tt, trainX.shape[1], axis=-1)
    y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]
    pre_df.extend(y_pred_future)
    
    ttt=test_generator[i][1]
    true_copies = np.repeat(ttt, trainX.shape[1], axis=-1)
    y_true_future = scaler.inverse_transform(true_copies)[:,0]
    tru_df.extend(y_true_future)
# Out:
# 1/1 [==============================] - 0s 300ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
len(pre_df),len(tru_df)
# Out:
# (9, 9)

# %%
plt.plot(pre_df, label='true')
plt.plot(tru_df, label='preduct')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Raw vs. Smooth Signal')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rms = sqrt(mean_squared_error(pre_df, tru_df))
rms
# Out:
# 5.596468798260085

# %%
from tensorflow.keras.models import load_model
model_2=load_model('star_pro_weights_2.1.h5', compile=False)

pre_df=[]
tru_df=[]

for i in range(len(test_generator)):
    tt=model_2.predict(test_generator[i][0])
    prediction_copies = np.repeat(tt, trainX.shape[1], axis=-1)
    y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]
    pre_df.extend(y_pred_future)
    
    ttt=test_generator[i][1]
    true_copies = np.repeat(ttt, trainX.shape[1], axis=-1)
    y_true_future = scaler.inverse_transform(true_copies)[:,0]
    tru_df.extend(y_true_future)

from sklearn.metrics import mean_squared_error
from math import sqrt
print('rms =', sqrt(mean_squared_error(pre_df, tru_df)))

plt.plot(pre_df, label='true')
plt.plot(tru_df, label='preduct')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Raw vs. Smooth Signal')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 285ms/step
# 1/1 [==============================] - 0s 41ms/step
# rms = 14.352342082320531
